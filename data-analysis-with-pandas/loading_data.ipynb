# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'employees.csv',
#  'jupyter_notebook.ipynb',
#  'loading_data.ipynb',
#  'main.py',
#  'read.csv',
#  'rows.json']

# %%
import pandas

# %%
df1 = pandas.read_csv("read.csv", header=None)

# %%
df1
# Out:
#                                                       0
# 0     2018-01-01 00:01:01;read;country_7;2458151261;...
# 1     2018-01-01 00:03:20;read;country_7;2458151262;...
# 2     2018-01-01 00:04:01;read;country_7;2458151263;...
# 3     2018-01-01 00:04:02;read;country_7;2458151264;...
# 4     2018-01-01 00:05:03;read;country_8;2458151265;...
# ...                                                 ...
# 1790  2018-01-01 23:57:14;read;country_2;2458153051;...
# 1791  2018-01-01 23:58:33;read;country_8;2458153052;...
# 1792  2018-01-01 23:59:36;read;country_6;2458153053;...
# 1793  2018-01-01 23:59:36;read;country_7;2458153054;...
# 1794  2018-01-01 23:59:38;read;country_5;2458153055;...
#
# [1795 rows x 1 columns]

# %%
df2 = pandas.read_csv("employees.csv")

# %%
df2
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df2.set_index("First Name") # We can use an id or any serial number also
# Out:
#             Gender  Start Date Last Login Time  Salary  Bonus %  \
# First Name
# Douglas       Male    8/6/1993        12:42 PM   97308    6.945
# Thomas        Male   3/31/1996         6:53 AM   61933    4.170
# Maria       Female   4/23/1993        11:17 AM  130590   11.858
# Jerry         Male    3/4/2005         1:00 PM  138705    9.340
# Larry         Male   1/24/1998         4:47 PM  101004    1.389
# ...            ...         ...             ...     ...      ...
# Henry          NaN  11/23/2014         6:09 AM  132483   16.655
# Phillip       Male   1/31/1984         6:30 AM   42392   19.675
# Russell       Male   5/20/2013        12:39 PM   96914    1.421
# Larry         Male   4/20/2013         4:45 PM   60500   11.985
# Albert        Male   5/15/2012         6:24 PM  129949   10.169
#
#            Senior Management                  Team
# First Name
# Douglas                 True             Marketing
# Thomas                  True                   NaN
# ...

# %%
df2.shape
# Out:
# (1000, 8)

# %%
df3 = pandas.read_json("supermarkets.json")
df3
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4 = pandas.read_excel("supermarkets.xlsx", sheetname=0)

# %%
df5 = pandas.read_csv("supermarkets_commas.txt")

# %%
df6 = pandas.read_csv("supermarkets_semi-colons.txt", separater=";")

# %%
pandas.read_csv?

# %%
df7 = pandas.read_csv("http://pythonhow.com/supermarkets.csv")
df7
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20
